# %% [markdown]
# Drive Connection
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# ```
# Directory Match
# ```
# cd /content/drive/MyDrive/commit-cloab/Remember_Python_Basics
# ```
# Gih Hub connection
# ```
# !git config --global user.email "forkwntkd96@gmail.com"
# !git config --global user.name "lee-edgar"
# ```
# git commit & push
# ```
# !git add .ipynb
# !git commit -m " blra blra"
# !git push
# ```

# %%
#Drive Connection
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd /content/drive/MyDrive/commit-colab/Remember_Python_Basics
# !git config --global user.email "forkwntkd96@gmail.com"
# !git config --global user.name "lee-edgar"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9de00317f663> in <module>()
# ----> 1 cd /content/drive/MyDrive/commit-colab/Remember_Python_Basics
#       2 get_ipython().system('git config --global user.email "forkwntkd96@gmail.com"')
#       3 get_ipython().system('git config --global user.name "lee-edgar"')
#
# NameError: name 'cd' is not defined

# %%
# !git add cloning.ipynb
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git commit -m "colab & github cloning test"
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
