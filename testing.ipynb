# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd /content/drive/MyDrive/commit-colab/Remember_Python_Basics
# Out:
# /content/drive/MyDrive/commit-colab/Remember_Python_Basics

# %%
# !git config --global user.email "forkwntkd96@gmail.com"
# !git config --global user.name ""
# Out:
# README.md  testing.ipynb
